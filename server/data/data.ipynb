# %%
from faker import Faker
import random
import csv
fake = Faker()

TRAINING_DATA_SIZE = 50

fields = ["id",
    "name",
    "cgpa",
    "backend",
    "frontend",
    "database",
    "android",
    "ios",
    "cross_platform",
    "version_control_systems",
    "python",
    "multivariate_calculus_linear_algebra",
    "probability_statistics",
    "ml_algorithms",
    "communication_networks",
    "operating_system",
    "data_structures",
    "algorithms",
    "problem_solving_and_aptitude",
    "resume"
]

DATA_FILE_NAME = "data.csv"

RESUME_LINKS = [
    "https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view",
    "https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk",
    "https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1"
]

names = []
cgpa = []
backend = []
frontend = []
database = []
android = []
ios = []
cross_platform = []
version_control_systems = []
python = []
multivariate_calculus_linear_algebra = []
probability_statistics = []
ml_algorithms = []
communication_networks = []
operating_system = []
data_structures = []
algorithms = []
problem_solving_aptitude = []
resumes = []

for i in range(TRAINING_DATA_SIZE):
    names.append(fake.name())
    cgpa.append(random.uniform(5, 10))
    backend.append(random.randint(0, 10))
    frontend.append(random.randint(0, 10))
    database.append(random.randint(0, 10))
    android.append(random.randint(0, 10))
    ios.append(random.randint(0, 10))
    cross_platform.append(random.randint(0, 10))
    version_control_systems.append(random.randint(0, 10))
    python.append(random.randint(0, 10))
    multivariate_calculus_linear_algebra.append(random.randint(0, 10))
    probability_statistics.append(random.randint(0, 10))
    ml_algorithms.append(random.randint(0, 10))
    communication_networks.append(random.randint(0, 10))
    operating_system.append(random.randint(0, 10))
    data_structures.append(random.randint(0, 10))
    algorithms.append(random.randint(0, 10))
    problem_solving_aptitude.append(random.randint(0, 10))
    resumes.append(RESUME_LINKS[random.randint(0, RESUME_LINKS.__len__() - 1)])

dataset = []
for i in range(TRAINING_DATA_SIZE):
    temp = []
    temp.append(1001+i)
    temp.append(names[i])
    temp.append(cgpa[i])
    temp.append(backend[i])
    temp.append(frontend[i])
    temp.append(database[i])
    temp.append(android[i])
    temp.append(ios[i])
    temp.append(cross_platform[i])
    temp.append(version_control_systems[i])
    temp.append(python[i])
    temp.append(multivariate_calculus_linear_algebra[i])
    temp.append(probability_statistics[i])
    temp.append(ml_algorithms[i])
    temp.append(communication_networks[i])
    temp.append(operating_system[i])
    temp.append(data_structures[i])
    temp.append(algorithms[i])
    temp.append(problem_solving_aptitude[i])
    temp.append(resumes[i])
    dataset.append(temp)

with open(DATA_FILE_NAME, 'w', newline='') as csvFile:
    csvWriter = csv.writer(csvFile)
    csvWriter.writerow(fields)
    csvWriter.writerows(dataset)

# %%
import pandas as pd
import firebase_admin
from firebase_admin import credentials, firestore

cred = credentials.Certificate("../firebase.json")

firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://devathon.firebaseio.com'
})

db = firestore.client()
doc_ref = db.collection(u'applications')

df = pd.read_csv('data.csv')
tmp = df.to_dict(orient='records')
list(map(lambda x: doc_ref.add(x), tmp))

docs = doc_ref.stream()
for doc in docs:
    print(f'{doc.id} => {doc.to_dict()}')
# Out:
# 2ScSLTtokbcjHPDBuu2t => {'algorithms': 4, 'backend': 0, 'id': 1006, 'database': 1, 'data_structures': 1, 'cgpa': 6.150105708904398, 'android': 4, 'ios': 6, 'name': 'Angela Atkins', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 9, 'python': 5, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 1, 'communication_networks': 4, 'probability_statistics': 9, 'problem_solving_and_aptitude': 5, 'operating_system': 1, 'cross_platform': 2, 'version_control_systems': 10}
# 2ig9QqhKjND4r6tH35SU => {'backend': 3, 'id': 1044, 'algorithms': 1, 'data_structures': 0, 'database': 1, 'cgpa': 9.297384732761014, 'android': 2, 'ml_algorithms': 4, 'name': 'Jerry Levy', 'ios': 7, 'multivariate_calculus_linear_algebra': 2, 'python': 3, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 2, 'communication_networks': 8, 'probability_statistics': 0, 'problem_solving_and_aptitude': 5, 'operating_system': 7, 'cross_platform': 5, 'version_control_systems': 10}
# 61OK7ca5T9TK7rSrNozC => {'id': 1047, 'backend': 7, 'algorithms': 0, 'data_structures': 8, 'database': 6, 'cgpa': 8.501026332338835, 'android': 4, 'ml_algorithms': 0, 'name': 'Daniel Brady', 'ios': 0, 'multivariate_calculus_linear_algebra': 6, 'python': 6, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 3, 'communication_networks': 3, 'probability_statistics': 2, 'problem_solving_and_aptitude': 2, 'operating_system': 6, 'cross_platform': 5, 'version_control_systems': 6}
# 72xRylwTG0iqDfsAApie => {'algorithms': 0, 'backend': 6, 'id': 1034, 'database': 4, 'data_structures': 8, 'cgpa': 7.724629336796598, 'android': 9, 'ios': 7, 'name': 'Troy Young', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 8, 'python': 2, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 4, 'communication_networks': 0, 'version_control_systems': 9, 'problem_solving_and_aptitude': 6, 'operating_system': 4, 'cross_platform': 1, 'probability_statistics': 2}
# 8WVwIdoi1XHd7uToW5eP => {'backend': 0, 'id': 1012, 'algorithms': 5, 'database': 7, 'data_structures': 5, 'cgpa': 5.872581062233925, 'android': 2, 'ml_algorithms': 10, 'name': 'Eric Fisher', 'ios': 3, 'multivariate_calculus_linear_algebra': 5, 'python': 1, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 5, 'communication_networks': 8, 'version_control_systems': 3, 'problem_solving_and_aptitude': 6, 'operating_system': 0, 'cross_platform': 5, 'probability_statistics': 1}
# 9p388bZx7AxAHz8a297o => {'id': 1049, 'algorithms': 2, 'backend': 9, 'data_structures': 9, 'database': 2, 'cgpa': 8.945405507343619, 'android': 3, 'ios': 3, 'name': 'Matthew Gomez', 'ml_algorithms': 1, 'multivariate_calculus_linear_algebra': 9, 'python': 6, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 2, 'communication_networks': 0, 'probability_statistics': 7, 'problem_solving_and_aptitude': 4, 'operating_system': 4, 'cross_platform': 1, 'version_control_systems': 5}
# BRdXxOQ6hbdxv4vltPzj => {'algorithms': 10, 'backend': 5, 'id': 1038, 'data_structures': 4, 'database': 3, 'cgpa': 6.895751569648509, 'android': 9, 'ml_algorithms': 6, 'name': 'Melissa Turner', 'ios': 7, 'multivariate_calculus_linear_algebra': 3, 'python': 4, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 7, 'communication_networks': 6, 'version_control_systems': 2, 'problem_solving_and_aptitude': 1, 'operating_system': 4, 'cross_platform': 7, 'probability_statistics': 1}
# DTnStDCzojcZUiacQrPe => {'backend': 1, 'algorithms': 6, 'id': 1040, 'data_structures': 10, 'database': 9, 'cgpa': 9.450529057329076, 'android': 8, 'ios': 6, 'name': 'Chad Shepherd', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 4, 'python': 3, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 0, 'communication_networks': 7, 'probability_statistics': 6, 'problem_solving_and_aptitude': 7, 'operating_system': 5, 'cross_platform': 5, 'version_control_systems': 1}
# EvuUYWPHZUS8oIticuNB => {'backend': 9, 'id': 1037, 'algorithms': 3, 'data_structures': 7, 'database': 2, 'cgpa': 7.058224682482863, 'android': 0, 'ml_algorithms': 5, 'name': 'Andrew Weiss', 'ios': 1, 'multivariate_calculus_linear_algebra': 10, 'python': 8, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 4, 'communication_networks': 6, 'version_control_systems': 1, 'problem_solving_and_aptitude': 5, 'operating_system': 7, 'cross_platform': 8, 'probability_statistics': 0}
# FOe3cipNuqw9gwL4IzwP => {'id': 1029, 'backend': 8, 'algorithms': 1, 'database': 8, 'data_structures': 1, 'cgpa': 5.590547710119896, 'android': 3, 'ios': 5, 'name': 'Lori Newman', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 10, 'python': 2, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 4, 'communication_networks': 0, 'version_control_systems': 4, 'problem_solving_and_aptitude': 2, 'operating_system': 0, 'cross_platform': 2, 'probability_statistics': 9}
# FzPN5BwBaZ5AUYm850sM => {'algorithms': 4, 'id': 1036, 'backend': 8, 'database': 9, 'data_structures': 3, 'cgpa': 5.897815880516999, 'android': 9, 'ios': 7, 'name': 'Patrick Shepard', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 4, 'python': 6, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 6, 'communication_networks': 4, 'probability_statistics': 2, 'problem_solving_and_aptitude': 4, 'operating_system': 0, 'cross_platform': 3, 'version_control_systems': 5}
# GvhLSREttZpAPVSMcP4p => {'algorithms': 6, 'backend': 5, 'id': 1017, 'data_structures': 4, 'database': 1, 'cgpa': 8.065414234720329, 'android': 9, 'ml_algorithms': 6, 'name': 'Elizabeth Villa', 'ios': 6, 'multivariate_calculus_linear_algebra': 1, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 4, 'communication_networks': 3, 'version_control_systems': 5, 'problem_solving_and_aptitude': 9, 'operating_system': 1, 'cross_platform': 6, 'probability_statistics': 8}
# H7fncT7HcYaxY1otpaKy => {'backend': 7, 'algorithms': 8, 'id': 1021, 'data_structures': 4, 'database': 1, 'cgpa': 6.967758174478095, 'android': 6, 'ios': 9, 'name': 'Michael Palmer', 'ml_algorithms': 0, 'multivariate_calculus_linear_algebra': 1, 'python': 5, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 5, 'probability_statistics': 10, 'problem_solving_and_aptitude': 4, 'operating_system': 0, 'cross_platform': 9, 'version_control_systems': 7}
# HYhSWSjK1nkEBnv3Th5S => {'backend': 1, 'id': 1019, 'algorithms': 1, 'data_structures': 9, 'database': 0, 'cgpa': 6.683440409878957, 'android': 3, 'ios': 3, 'name': 'Phyllis Richard', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 9, 'python': 8, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 9, 'communication_networks': 0, 'probability_statistics': 1, 'problem_solving_and_aptitude': 6, 'operating_system': 3, 'cross_platform': 6, 'version_control_systems': 2}
# JZNYXi8vnlxLX7frLZNF => {'id': 1041, 'algorithms': 2, 'backend': 8, 'database': 3, 'data_structures': 10, 'cgpa': 7.935710840811668, 'android': 4, 'ios': 1, 'name': 'Joshua Elliott', 'ml_algorithms': 9, 'multivariate_calculus_linear_algebra': 0, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 8, 'version_control_systems': 6, 'problem_solving_and_aptitude': 8, 'operating_system': 7, 'cross_platform': 5, 'probability_statistics': 10}
# KZDQqUK67cFpJLX3aB7y => {'algorithms': 3, 'backend': 8, 'id': 1043, 'data_structures': 1, 'database': 7, 'cgpa': 6.641728135036863, 'android': 7, 'ml_algorithms': 10, 'name': 'Jessica Clark', 'ios': 1, 'multivariate_calculus_linear_algebra': 6, 'python': 4, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 7, 'communication_networks': 8, 'probability_statistics': 3, 'problem_solving_and_aptitude': 1, 'operating_system': 0, 'cross_platform': 2, 'version_control_systems': 4}
# LblQhNutljSrniE2WnBP => {'id': 1042, 'algorithms': 8, 'backend': 6, 'database': 1, 'data_structures': 1, 'cgpa': 7.800931369874118, 'android': 9, 'ml_algorithms': 5, 'name': 'Jane Reyes', 'ios': 9, 'multivariate_calculus_linear_algebra': 9, 'python': 2, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 10, 'communication_networks': 6, 'version_control_systems': 2, 'problem_solving_and_aptitude': 6, 'operating_system': 6, 'cross_platform': 1, 'probability_statistics': 5}
# MgwrzFq0eJPRM4L4FE7z => {'backend': 6, 'algorithms': 9, 'id': 1001, 'database': 6, 'data_structures': 7, 'cgpa': 7.96610370174997, 'android': 6, 'ios': 7, 'name': 'Brooke Wright', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 1, 'python': 2, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 5, 'probability_statistics': 8, 'problem_solving_and_aptitude': 7, 'operating_system': 5, 'cross_platform': 6, 'version_control_systems': 3}
# P0NigEUFfMdk3ymGqUxX => {'id': 1039, 'algorithms': 1, 'backend': 0, 'data_structures': 8, 'database': 10, 'cgpa': 5.512060133687754, 'android': 0, 'ml_algorithms': 8, 'name': 'Angela Miller', 'ios': 2, 'multivariate_calculus_linear_algebra': 2, 'python': 0, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 6, 'communication_networks': 1, 'probability_statistics': 2, 'problem_solving_and_aptitude': 1, 'operating_system': 6, 'cross_platform': 4, 'version_control_systems': 5}
# PUOzmIZjp6s4vHcUMybg => {'algorithms': 7, 'backend': 0, 'id': 1025, 'data_structures': 1, 'database': 10, 'cgpa': 5.972910207830401, 'android': 9, 'ml_algorithms': 5, 'name': 'Faith Jensen', 'ios': 2, 'multivariate_calculus_linear_algebra': 1, 'python': 7, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 9, 'communication_networks': 5, 'version_control_systems': 10, 'problem_solving_and_aptitude': 3, 'operating_system': 1, 'cross_platform': 2, 'probability_statistics': 1}
# QTfmqtGMm8NhmPyuNV2B => {'id': 1050, 'algorithms': 10, 'backend': 1, 'database': 1, 'data_structures': 7, 'cgpa': 5.665149279293241, 'android': 8, 'ml_algorithms': 10, 'name': 'Joseph Perkins', 'ios': 7, 'multivariate_calculus_linear_algebra': 4, 'python': 3, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 3, 'probability_statistics': 0, 'problem_solving_and_aptitude': 5, 'operating_system': 5, 'cross_platform': 1, 'version_control_systems': 5}
# QdPo8I4bOwhVb9vYpv4F => {'backend': 9, 'id': 1045, 'algorithms': 7, 'database': 5, 'data_structures': 0, 'cgpa': 6.741889885845312, 'android': 5, 'ios': 10, 'name': 'Jay Howard', 'ml_algorithms': 7, 'multivariate_calculus_linear_algebra': 3, 'python': 3, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 5, 'version_control_systems': 7, 'problem_solving_and_aptitude': 9, 'operating_system': 0, 'cross_platform': 1, 'probability_statistics': 10}
# RZVgzfoBwczH9uJcSaA0 => {'algorithms': 9, 'backend': 5, 'id': 1031, 'database': 2, 'data_structures': 4, 'cgpa': 8.576798831093237, 'android': 3, 'ml_algorithms': 4, 'name': 'Anna Nelson', 'ios': 7, 'multivariate_calculus_linear_algebra': 8, 'python': 2, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 7, 'communication_networks': 7, 'version_control_systems': 4, 'problem_solving_and_aptitude': 7, 'operating_system': 7, 'cross_platform': 5, 'probability_statistics': 5}
# UcuHCRH18oO8PgsSfa7H => {'id': 1008, 'algorithms': 2, 'backend': 8, 'database': 6, 'data_structures': 9, 'cgpa': 6.050323557545752, 'android': 4, 'ios': 6, 'name': 'Catherine Bernard', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 1, 'python': 1, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 3, 'communication_networks': 6, 'version_control_systems': 2, 'problem_solving_and_aptitude': 5, 'operating_system': 4, 'cross_platform': 7, 'probability_statistics': 0}
# UukJi85AX26sTZdx5w6d => {'id': 1004, 'algorithms': 0, 'backend': 5, 'data_structures': 2, 'database': 2, 'cgpa': 5.970067891558488, 'android': 2, 'ml_algorithms': 10, 'name': 'Michael Clark', 'ios': 8, 'multivariate_calculus_linear_algebra': 0, 'python': 4, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 7, 'communication_networks': 10, 'probability_statistics': 7, 'problem_solving_and_aptitude': 8, 'operating_system': 4, 'cross_platform': 5, 'version_control_systems': 10}
# UyuHxUfm70fd1fOPYyBE => {'algorithms': 0, 'id': 1010, 'backend': 5, 'database': 6, 'data_structures': 1, 'cgpa': 6.019026724337371, 'android': 7, 'ios': 6, 'name': 'John Hines', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 5, 'python': 5, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 3, 'communication_networks': 5, 'probability_statistics': 8, 'problem_solving_and_aptitude': 4, 'operating_system': 0, 'cross_platform': 2, 'version_control_systems': 6}
# WBAo6RNSoRbsGdJBlb6B => {'algorithms': 0, 'backend': 6, 'id': 1024, 'data_structures': 1, 'database': 3, 'cgpa': 9.050540607010191, 'android': 9, 'ios': 9, 'name': 'Joshua Thompson', 'ml_algorithms': 8, 'multivariate_calculus_linear_algebra': 2, 'python': 2, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 6, 'communication_networks': 0, 'probability_statistics': 4, 'problem_solving_and_aptitude': 3, 'operating_system': 0, 'cross_platform': 0, 'version_control_systems': 8}
# Xky1pAQkX7JPq7KLG82f => {'backend': 4, 'id': 1013, 'algorithms': 1, 'database': 4, 'data_structures': 0, 'cgpa': 6.381478814804012, 'android': 10, 'ios': 0, 'name': 'Alexander Campbell', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 5, 'python': 0, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 2, 'communication_networks': 5, 'probability_statistics': 10, 'problem_solving_and_aptitude': 1, 'operating_system': 4, 'cross_platform': 10, 'version_control_systems': 1}
# Zpw1H9N1th8Op7EbSG0l => {'backend': 2, 'algorithms': 4, 'id': 1048, 'data_structures': 5, 'database': 5, 'cgpa': 8.439321564465608, 'android': 5, 'ml_algorithms': 4, 'name': 'Christopher Phillips', 'ios': 8, 'multivariate_calculus_linear_algebra': 2, 'python': 10, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 6, 'communication_networks': 10, 'version_control_systems': 3, 'problem_solving_and_aptitude': 5, 'operating_system': 5, 'cross_platform': 2, 'probability_statistics': 10}
# axwy962fU3uYM1pwugJe => {'backend': 1, 'algorithms': 9, 'id': 1033, 'database': 8, 'data_structures': 7, 'cgpa': 8.45339158365992, 'android': 5, 'ml_algorithms': 3, 'name': 'Jeffrey Adams', 'ios': 1, 'multivariate_calculus_linear_algebra': 1, 'python': 0, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 9, 'communication_networks': 8, 'probability_statistics': 1, 'problem_solving_and_aptitude': 1, 'operating_system': 9, 'cross_platform': 7, 'version_control_systems': 9}
# cDokxVarZfsDiaEKROm4 => {'algorithms': 10, 'id': 1016, 'backend': 7, 'database': 8, 'data_structures': 8, 'cgpa': 5.706149631535687, 'android': 3, 'ml_algorithms': 4, 'name': 'Diane Jacobs', 'ios': 9, 'multivariate_calculus_linear_algebra': 0, 'python': 10, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 0, 'communication_networks': 8, 'probability_statistics': 0, 'problem_solving_and_aptitude': 4, 'operating_system': 1, 'cross_platform': 4, 'version_control_systems': 6}
# fAI7XhtF1QOdfi3ADi4a => {'backend': 0, 'id': 1020, 'algorithms': 6, 'database': 4, 'data_structures': 3, 'cgpa': 7.708195139728738, 'android': 10, 'ios': 7, 'name': 'Christopher Jones', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 10, 'python': 4, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 6, 'communication_networks': 10, 'version_control_systems': 4, 'problem_solving_and_aptitude': 7, 'operating_system': 4, 'cross_platform': 3, 'probability_statistics': 1}
# j4WuzKp8o6qOVlSWf6YQ => {'id': 1007, 'backend': 8, 'algorithms': 6, 'data_structures': 10, 'database': 9, 'cgpa': 5.596508618747215, 'android': 6, 'ios': 10, 'name': 'Matthew Cox', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 7, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 9, 'communication_networks': 9, 'version_control_systems': 1, 'problem_solving_and_aptitude': 2, 'operating_system': 6, 'cross_platform': 3, 'probability_statistics': 10}
# jIqjiLuPP3JfrinF3O3f => {'algorithms': 2, 'id': 1009, 'backend': 1, 'database': 0, 'data_structures': 2, 'cgpa': 8.329338605181714, 'android': 6, 'ml_algorithms': 10, 'name': 'Laura Webster', 'ios': 5, 'multivariate_calculus_linear_algebra': 2, 'python': 2, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 1, 'communication_networks': 1, 'probability_statistics': 3, 'problem_solving_and_aptitude': 6, 'operating_system': 6, 'cross_platform': 4, 'version_control_systems': 9}
# kTOzpqeGZuxuYhVnNwg4 => {'algorithms': 9, 'backend': 0, 'id': 1011, 'data_structures': 2, 'database': 9, 'cgpa': 7.136684995285121, 'android': 2, 'ios': 8, 'name': 'Whitney Adams', 'ml_algorithms': 6, 'multivariate_calculus_linear_algebra': 6, 'python': 3, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 7, 'communication_networks': 7, 'version_control_systems': 6, 'problem_solving_and_aptitude': 4, 'operating_system': 7, 'cross_platform': 10, 'probability_statistics': 10}
# khhRIPG1CzNn9ISzflMD => {'id': 1028, 'backend': 0, 'algorithms': 0, 'database': 7, 'data_structures': 10, 'cgpa': 7.38777781805461, 'android': 3, 'ml_algorithms': 7, 'name': 'Terri Mccullough PhD', 'ios': 0, 'multivariate_calculus_linear_algebra': 6, 'python': 4, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 10, 'probability_statistics': 2, 'problem_solving_and_aptitude': 5, 'operating_system': 2, 'cross_platform': 2, 'version_control_systems': 3}
# kydt6RTFQH2gAvkflmYl => {'backend': 6, 'algorithms': 6, 'id': 1032, 'database': 6, 'data_structures': 5, 'cgpa': 9.054902689098151, 'android': 8, 'ml_algorithms': 5, 'name': 'Vincent Gomez', 'ios': 10, 'multivariate_calculus_linear_algebra': 2, 'python': 3, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 10, 'communication_networks': 2, 'version_control_systems': 7, 'problem_solving_and_aptitude': 2, 'operating_system': 6, 'cross_platform': 4, 'probability_statistics': 3}
# lrDynUeDerVH2WFn7H9g => {'algorithms': 0, 'backend': 3, 'id': 1018, 'data_structures': 7, 'database': 0, 'cgpa': 9.827652242560932, 'android': 7, 'ios': 3, 'name': 'Alexis Sanchez', 'ml_algorithms': 4, 'multivariate_calculus_linear_algebra': 8, 'python': 9, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 5, 'version_control_systems': 1, 'problem_solving_and_aptitude': 4, 'operating_system': 3, 'cross_platform': 8, 'probability_statistics': 4}
# mFF1VmimbEaojJnxJM57 => {'algorithms': 3, 'id': 1035, 'backend': 6, 'data_structures': 1, 'database': 3, 'cgpa': 7.864106259873706, 'android': 2, 'ios': 4, 'name': 'Andrea Stewart', 'ml_algorithms': 2, 'multivariate_calculus_linear_algebra': 7, 'python': 5, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 9, 'communication_networks': 9, 'probability_statistics': 0, 'problem_solving_and_aptitude': 1, 'operating_system': 8, 'cross_platform': 4, 'version_control_systems': 2}
# o0IY1nglcdzFckXMFOgj => {'algorithms': 4, 'id': 1026, 'backend': 1, 'database': 1, 'data_structures': 5, 'cgpa': 8.295311831624339, 'android': 4, 'ios': 9, 'name': 'Sandra Gray', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 2, 'python': 1, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 6, 'communication_networks': 8, 'probability_statistics': 5, 'problem_solving_and_aptitude': 0, 'operating_system': 2, 'cross_platform': 10, 'version_control_systems': 2}
# oIENHTaIDCQYuSatsHvh => {'algorithms': 0, 'id': 1015, 'backend': 4, 'data_structures': 7, 'database': 6, 'cgpa': 7.568835814352564, 'android': 9, 'ios': 3, 'name': 'Christopher Price', 'ml_algorithms': 3, 'multivariate_calculus_linear_algebra': 2, 'python': 10, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 7, 'communication_networks': 3, 'probability_statistics': 3, 'problem_solving_and_aptitude': 8, 'operating_system': 4, 'cross_platform': 1, 'version_control_systems': 1}
# p8dqvqRb2SjhkrhNVzwz => {'id': 1014, 'backend': 4, 'algorithms': 5, 'database': 6, 'data_structures': 4, 'cgpa': 5.185570633720596, 'android': 8, 'ml_algorithms': 8, 'name': 'Latoya Briggs MD', 'ios': 8, 'multivariate_calculus_linear_algebra': 2, 'python': 8, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 2, 'communication_networks': 1, 'probability_statistics': 4, 'problem_solving_and_aptitude': 6, 'operating_system': 6, 'cross_platform': 5, 'version_control_systems': 8}
# qtO4erHL3UCnuWuDEu9p => {'algorithms': 7, 'id': 1046, 'backend': 3, 'data_structures': 9, 'database': 10, 'cgpa': 9.964324111410752, 'android': 5, 'ml_algorithms': 10, 'name': 'Dustin Yates', 'ios': 6, 'multivariate_calculus_linear_algebra': 6, 'python': 1, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 3, 'communication_networks': 2, 'probability_statistics': 6, 'problem_solving_and_aptitude': 5, 'operating_system': 4, 'cross_platform': 4, 'version_control_systems': 2}
# sKLgN6m6CzMIdXMCZr1F => {'backend': 10, 'id': 1023, 'algorithms': 1, 'data_structures': 4, 'database': 7, 'cgpa': 7.382356544118762, 'android': 8, 'ios': 9, 'name': 'Andrew James', 'ml_algorithms': 9, 'multivariate_calculus_linear_algebra': 5, 'python': 0, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 1, 'probability_statistics': 6, 'problem_solving_and_aptitude': 2, 'operating_system': 6, 'cross_platform': 7, 'version_control_systems': 4}
# sb2HX3oP8K6qmrSCwK9j => {'algorithms': 3, 'backend': 1, 'id': 1005, 'data_structures': 0, 'database': 2, 'cgpa': 6.94905252075679, 'android': 9, 'ml_algorithms': 3, 'name': 'Michael Palmer', 'ios': 5, 'multivariate_calculus_linear_algebra': 0, 'python': 8, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 0, 'communication_networks': 2, 'version_control_systems': 6, 'problem_solving_and_aptitude': 4, 'operating_system': 4, 'cross_platform': 4, 'probability_statistics': 8}
# xKvkCVq9yMmZDYociD0A => {'algorithms': 5, 'backend': 3, 'id': 1030, 'database': 3, 'data_structures': 0, 'cgpa': 6.867696535285137, 'android': 1, 'ml_algorithms': 8, 'name': 'Edgar Pacheco', 'ios': 7, 'multivariate_calculus_linear_algebra': 8, 'python': 10, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 9, 'communication_networks': 5, 'probability_statistics': 8, 'problem_solving_and_aptitude': 9, 'operating_system': 0, 'cross_platform': 0, 'version_control_systems': 3}
# yA42AYV6mPzLQibOozKP => {'id': 1002, 'backend': 1, 'algorithms': 4, 'data_structures': 9, 'database': 6, 'cgpa': 8.939990091139933, 'android': 1, 'ml_algorithms': 0, 'name': 'Nathaniel Bond', 'ios': 2, 'multivariate_calculus_linear_algebra': 2, 'python': 1, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 8, 'communication_networks': 8, 'version_control_systems': 1, 'problem_solving_and_aptitude': 0, 'operating_system': 6, 'cross_platform': 4, 'probability_statistics': 8}
# yJ2xme9U8NvUjUos605K => {'algorithms': 4, 'backend': 10, 'id': 1003, 'data_structures': 9, 'database': 0, 'cgpa': 8.271083172141786, 'android': 1, 'ios': 2, 'name': 'Mary Taylor', 'ml_algorithms': 5, 'multivariate_calculus_linear_algebra': 10, 'python': 6, 'resume': 'https://drive.google.com/file/d/1hQn6N6r6uV5hm_UH5PNi6zVFF4QAzq7p/view?usp=drivesdk', 'frontend': 8, 'communication_networks': 10, 'probability_statistics': 3, 'problem_solving_and_aptitude': 3, 'operating_system': 6, 'cross_platform': 7, 'version_control_systems': 6}
# zEkKb5dJNgqOI5Dfv4EL => {'algorithms': 5, 'backend': 10, 'id': 1027, 'data_structures': 7, 'database': 8, 'cgpa': 6.740303303653009, 'android': 4, 'ml_algorithms': 6, 'name': 'Mary Jordan', 'ios': 2, 'multivariate_calculus_linear_algebra': 1, 'python': 10, 'resume': 'https://drive.google.com/file/d/10ssHE1XZVfGH-09LN9Yp0KCGbQXuATCv/view?ts=637670d1', 'frontend': 7, 'communication_networks': 5, 'version_control_systems': 7, 'problem_solving_and_aptitude': 6, 'operating_system': 1, 'cross_platform': 6, 'probability_statistics': 7}
# zLAxSE7HjAagbemjwtpo => {'id': 1022, 'algorithms': 7, 'backend': 1, 'database': 9, 'data_structures': 7, 'cgpa': 5.467532119079101, 'android': 9, 'ios': 4, 'name': 'Joshua Wise', 'ml_algorithms': 9, 'multivariate_calculus_linear_algebra': 8, 'python': 2, 'resume': 'https://drive.google.com/file/d/1itqKZl2xKioEdFnoR1EHOQxZG4q_NpKo/view', 'frontend': 4, 'communication_networks': 8, 'probability_statistics': 5, 'problem_solving_and_aptitude': 7, 'operating_system': 8, 'cross_platform': 1, 'version_control_systems': 3}
